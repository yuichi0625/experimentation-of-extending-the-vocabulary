# %%
# !nvidia-smi
# Out:
# Mon Jan  2 01:50:27 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    24W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !python -V
# Out:
# Python 3.8.16

# %%
# !python -c "from tensorflow.python.client import device_lib; print(device_lib.list_local_devices())"
# Out:
# 2023-01-02 01:50:32.923577: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 16159394437140038751
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14415560704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14382202759805760862
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/experimentation/language-style-transfer/code
# Out:
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.max_rows', 200)

# %%
DATA_DIR = Path('../../data')
TRAIN_PAIR = 'en850-eo8000'
DEV_PAIR = 'en-eo'

TRAIN_DIR = DATA_DIR / 'train' / TRAIN_PAIR
DEV_DIR = DATA_DIR / 'dev' / DEV_PAIR
TEST_DIR = DATA_DIR / 'test' / DEV_PAIR
OUTPUT_DIR = Path('../../output') / TRAIN_PAIR / 'default'

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python style_transfer.py \
    --train {TRAIN_DIR}/train \
    --dev {DEV_DIR}/dev \
    --output {OUTPUT_DIR}/dev \
    --vocab {DATA_DIR}/vocab \
    --model {OUTPUT_DIR}/model \
    --steps_per_checkpoint 125
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 1,
#     'dev': '../../data/dev/en-eo/dev',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': False,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../../output/en850-eo8000/default/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../../output/en850-eo8000/default/dev',
#     'rho': 1,
#     'steps_per_checkpoint': 125,
#     'test': '',
#     'train': '../../data/train/en850-eo8000/train',
#     'vocab': '../../data/vocab'}
# ------------------------------------------------
# #sents of training file 0: 850
# #sents of training file 1: 8000
# vocabulary size: 37
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code/nn.py:9: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.nn.rnn_cell.GRUCell(dim)
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Creating model with fresh parameters.
# --------------------epoch 1--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [02:31<00:00, 13.98it/s]step 125, time 152s, loss 20.19, rec 18.21, adv 1.98, d0 1.35, d1 1.38
# 100% 125/125 [02:31<00:00,  1.21s/it]
# 100% 21/21 [00:01<00:00, 11.98it/s]
# dev loss 18.79, rec 16.84, adv 1.95, d0 1.51, d1 1.52
# saving model...
# --------------------epoch 2--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [01:15<00:00, 12.25it/s]step 250, time 230s, loss 13.78, rec 11.51, adv 2.26, d0 1.28, d1 1.28
# 100% 125/125 [01:15<00:00,  1.66it/s]
# 100% 21/21 [00:00<00:00, 26.26it/s]
# dev loss 12.78, rec 10.82, adv 1.96, d0 1.51, d1 1.39
# saving model...
# --------------------epoch 3--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:10<00:00, 13.73it/s]step 375, time 242s, loss 11.43, rec 9.14, adv 2.28, d0 1.20, d1 1.18
# 100% 125/125 [00:10<00:00, 12.05it/s]
# 100% 21/21 [00:00<00:00, 26.89it/s]
# dev loss 11.94, rec 9.63, adv 2.30, d0 1.27, d1 1.12
# saving model...
# --------------------epoch 4--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:10<00:00, 11.33it/s]step 500, time 255s, loss 10.65, rec 8.23, adv 2.41, d0 1.15, d1 1.14
# 100% 125/125 [00:10<00:00, 11.57it/s]
# 100% 21/21 [00:00<00:00, 26.95it/s]
# dev loss 12.55, rec 10.74, adv 1.81, d0 1.51, d1 1.27
# --------------------epoch 5--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:55<00:00,  2.82it/s]step 625, time 311s, loss 10.80, rec 8.23, adv 2.57, d0 1.08, d1 1.08
# 100% 125/125 [00:55<00:00,  2.25it/s]
# 100% 21/21 [00:00<00:00, 26.63it/s]
# dev loss 11.18, rec 9.19, adv 1.98, d0 1.50, d1 0.98
# saving model...
# --------------------epoch 6--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 11.43it/s]step 750, time 325s, loss 10.83, rec 8.14, adv 2.69, d0 1.08, d1 1.04
# 100% 125/125 [00:11<00:00, 10.73it/s]
# 100% 21/21 [00:00<00:00, 23.95it/s]
# dev loss 10.54, rec 8.28, adv 2.26, d0 1.24, d1 1.01
# saving model...
# --------------------epoch 7--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 10.97it/s]step 875, time 339s, loss 10.88, rec 8.12, adv 2.75, d0 1.00, d1 1.03
# 100% 125/125 [00:11<00:00, 10.61it/s]
# 100% 21/21 [00:00<00:00, 26.73it/s]
# dev loss 12.07, rec 9.78, adv 2.30, d0 1.69, d1 1.03
# --------------------epoch 8--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 11.65it/s]step 1000, time 351s, loss 10.65, rec 7.84, adv 2.82, d0 1.04, d1 1.01
# 100% 125/125 [00:11<00:00, 10.81it/s]
# 100% 21/21 [00:00<00:00, 26.16it/s]
# dev loss 10.63, rec 8.19, adv 2.44, d0 1.36, d1 0.95
# --------------------epoch 9--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 11.52it/s]step 1125, time 363s, loss 10.60, rec 7.73, adv 2.87, d0 0.97, d1 1.03
# 100% 125/125 [00:11<00:00, 10.76it/s]
# 100% 21/21 [00:00<00:00, 27.48it/s]
# dev loss 12.27, rec 9.28, adv 2.99, d0 1.46, d1 0.87
# --------------------epoch 10--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [01:01<00:00,  7.27it/s]step 1250, time 426s, loss 10.38, rec 7.44, adv 2.93, d0 0.97, d1 0.96
# 100% 125/125 [01:01<00:00,  2.02it/s]
# 100% 21/21 [00:00<00:00, 26.95it/s]
# dev loss 10.14, rec 7.89, adv 2.25, d0 1.08, d1 0.87
# saving model...
# --------------------epoch 11--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 11.05it/s]step 1375, time 440s, loss 10.44, rec 7.39, adv 3.05, d0 0.95, d1 0.94
# 100% 125/125 [00:12<00:00, 10.33it/s]
# 100% 21/21 [00:00<00:00, 27.02it/s]
# dev loss 10.65, rec 8.21, adv 2.43, d0 1.20, d1 0.89
# --------------------epoch 12--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 11.52it/s]step 1500, time 453s, loss 10.63, rec 7.42, adv 3.20, d0 0.93, d1 0.96
# 100% 125/125 [00:11<00:00, 10.60it/s]
# 100% 21/21 [00:00<00:00, 26.86it/s]
# dev loss 11.66, rec 8.70, adv 2.97, d0 1.87, d1 0.90
# --------------------epoch 13--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 11.07it/s]step 1625, time 465s, loss 10.67, rec 7.47, adv 3.20, d0 0.91, d1 0.94
# 100% 125/125 [00:11<00:00, 10.68it/s]
# 100% 21/21 [00:00<00:00, 26.98it/s]
# dev loss 10.65, rec 7.71, adv 2.94, d0 1.07, d1 0.82
# --------------------epoch 14--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 11.12it/s]step 1750, time 478s, loss 10.70, rec 7.38, adv 3.33, d0 0.92, d1 0.91
# 100% 125/125 [00:11<00:00, 10.73it/s]
# 100% 21/21 [00:00<00:00, 27.04it/s]
# dev loss 11.20, rec 8.36, adv 2.84, d0 1.50, d1 1.01
# --------------------epoch 15--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 11.17it/s]step 1875, time 490s, loss 10.95, rec 7.57, adv 3.38, d0 0.86, d1 0.89
# 100% 125/125 [00:11<00:00, 10.73it/s]
# 100% 21/21 [00:00<00:00, 27.16it/s]
# dev loss 11.75, rec 8.80, adv 2.95, d0 1.34, d1 1.00
# --------------------epoch 16--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 11.53it/s]step 2000, time 502s, loss 10.85, rec 7.40, adv 3.44, d0 0.95, d1 0.96
# 100% 125/125 [00:11<00:00, 10.87it/s]
# 100% 21/21 [00:00<00:00, 27.07it/s]
# dev loss 11.29, rec 7.89, adv 3.40, d0 1.60, d1 0.84
# --------------------epoch 17--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 11.20it/s]step 2125, time 515s, loss 10.90, rec 7.47, adv 3.43, d0 0.87, d1 0.89
# 100% 125/125 [00:11<00:00, 10.57it/s]
# 100% 21/21 [00:00<00:00, 27.17it/s]
# dev loss 12.48, rec 9.31, adv 3.17, d0 1.70, d1 0.98
# --------------------epoch 18--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 11.60it/s]step 2250, time 528s, loss 10.73, rec 7.20, adv 3.53, d0 0.81, d1 0.89
# 100% 125/125 [00:11<00:00, 10.51it/s]
# 100% 21/21 [00:00<00:00, 27.72it/s]
# dev loss 11.30, rec 8.13, adv 3.17, d0 1.28, d1 0.82
# --------------------epoch 19--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 12.04it/s]step 2375, time 540s, loss 10.80, rec 7.26, adv 3.54, d0 0.96, d1 0.92
# 100% 125/125 [00:11<00:00, 10.52it/s]
# 100% 21/21 [00:00<00:00, 27.29it/s]
# dev loss 11.66, rec 8.76, adv 2.90, d0 1.36, d1 0.81
# --------------------epoch 20--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.98it/s]step 2500, time 553s, loss 10.63, rec 7.17, adv 3.47, d0 0.82, d1 0.86
# 100% 125/125 [00:11<00:00, 10.44it/s]
# 100% 21/21 [00:00<00:00, 27.11it/s]
# dev loss 10.76, rec 7.92, adv 2.84, d0 1.30, d1 0.92

# %%
df_train = pd.read_csv(OUTPUT_DIR / 'dev.train_loss.tsv', sep='\t', header=0)
df_dev = pd.read_csv(OUTPUT_DIR / 'dev.dev_loss.tsv', sep='\t', header=0)

best_epoch = df_dev['loss'].argmin()
for path in OUTPUT_DIR.glob('*epoch*.tsf'):
    if f'epoch{best_epoch + 1}' not in str(path):
        path.unlink()

plt.figure(figsize=(15, 4))
for i, name in enumerate(df_train.columns, 1):
    plt.subplot(1, len(df_train.columns), i)
    plt.plot(df_train[name], color='blue', label='train')
    plt.plot(df_dev[name], color='red', label='dev')
    plt.axvline(best_epoch, color='green')
    plt.title(name)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python style_transfer.py \
    --test {TEST_DIR}/test \
    --output {OUTPUT_DIR}/test \
    --vocab {DATA_DIR}/vocab \
    --model {OUTPUT_DIR}/model \
    --load_model true \
    --beam 8
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 8,
#     'dev': '',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': True,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../../output/en850-eo8000/default/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../../output/en850-eo8000/default/test',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '../../data/test/en-eo/test',
#     'train': '',
#     'vocab': '../../data/vocab'}
# ------------------------------------------------
# vocabulary size: 37
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code/nn.py:9: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.nn.rnn_cell.GRUCell(dim)
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading model from ../../output/en850-eo8000/default/model
# 100% 21/21 [00:50<00:00,  2.40s/it]
# test loss 10.43, rec 8.18, adv 2.25, d0 1.07, d1 0.90

# %%
preexisting_words = set(
    line.split('\t')[0]
    for line
    in DATA_DIR.joinpath(f'{DEV_PAIR.split("-")[0]}_word2freq.tsv').read_text(encoding='utf-8').splitlines())

train_words = set(
    ''.join(word.split(' '))
    for word
    in TRAIN_DIR.joinpath('train.0').read_text(encoding='utf-8').splitlines())

tsf_words = [
    ''.join(word.split(' '))
    for word
    in OUTPUT_DIR.joinpath('test.1.tsf').read_text(encoding='utf-8').splitlines()]

print(f'transformed words: {len(tsf_words):,} (unique: {len(set(tsf_words)):,})')
ws = [w for w in tsf_words if w in train_words]
print(f'  preexisting English words seen during training: {len(ws):,} (unique: {len(set(ws)):,})')
ws = [w for w in tsf_words if w not in train_words and w in preexisting_words]
print(f'  preexisting English words not seen during training: {len(ws):,} (unique: {len(set(ws)):,})')
ws = [w for w in tsf_words if w not in preexisting_words]
print(f'  currently not in the English vocabulary: {len(ws):,} (unique: {len(set(ws)):,})')
# Out:
# transformed words: 1,300 (unique: 1,259)
#   preexisting English words seen during training: 43 (unique: 38)
#   preexisting English words not seen during training: 412 (unique: 389)
#   currently not in the English vocabulary: 845 (unique: 832)

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python style_transfer.py \
    --test {TEST_DIR}/paper \
    --output {OUTPUT_DIR}/paper \
    --vocab {DATA_DIR}/vocab \
    --model {OUTPUT_DIR}/model \
    --load_model true \
    --beam 8
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 8,
#     'dev': '',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': True,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../../output/en850-eo8000/default/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../../output/en850-eo8000/default/paper',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '../../data/test/en-eo/paper',
#     'train': '',
#     'vocab': '../../data/vocab'}
# ------------------------------------------------
# vocabulary size: 37
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code/nn.py:9: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.nn.rnn_cell.GRUCell(dim)
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading model from ../../output/en850-eo8000/default/model
# 100% 3/3 [00:09<00:00,  3.20s/it]
# test loss 8.98, rec 6.76, adv 2.22, d0 0.99, d1 1.00

# %%
df_paper = pd.read_csv(TEST_DIR / 'paper.1', header=None)
df_paper.columns = ['original']
df_paper_tsf = pd.read_csv(OUTPUT_DIR / 'paper.1.tsf', header=None)
df_paper_tsf.columns = ['transformed']

df_paper.join(df_paper_tsf)
# Out:
#                         original          transformed
# 0                  a r ĝ e n t o            a r e n t
# 1                a r ĝ e n t o n            r e a n t
# 2                      d a n k i              d a n i
# 3                    d a n k a s              d a n s
# 4                    b r a n ĉ o              b r a n
# 5                  b r a n ĉ o n            b r a n d
# 6                        m a ĉ o                m a y
# 7                      m a ĉ o n                m a n
# 8                      m a t ĉ o                m a t
# 9                    m a t ĉ o n              m a t y
# 10                 s u f i k s o            s u f i s
# 11               s u f i k s o n          s u f i n c
# 12                 p r e c i p e        p r e c i e c
# 13                       f i g o                f i g
# 14                     f i g o n              f i n g
# 15                   t i m e m a              t i m e
# 16                 t i m e m a j          t i m e a m
# 17                 t i m e m a n            t i m e n
# 18               t i m e m a j n          t i m e a m
# 19               g r a n d e g a        r i n d e a d
# 20             g r a n d e g a j      g r e a n d e s
# 21             g r a n d e g a n      g r e a n d e n
# 22           g r a n d e g a j n      g r e n a d e n
# 23                 f r a t i n o          f a r i n t
# 24               f r a t i n o n          f a r i n t
# 25                     ŝ t a l o              s t a l
# 26                   ŝ t a l o n              t a l l
# 27                 d i s k u t i          d i s t i n
# 28               d i s k u t a s          d i s u s t
# 29                   a n t a ŭ a                a n t
# 30                 a n t a ŭ a j            a n t a y
# 31                 a n t a ŭ a n            a n t a y
# 32               a n t a ŭ a j n            a n t a y
# 33                   a n t a ŭ e              a n t e
# 34                 a n t a ŭ e n          a n t e a n
# 35                     s e n d i              s e d n
# 36                   s e n d a s              s e d s
# 37                   s i m i l a              s i m l
# 38                 s i m i l a j          s i m i l l
# 39                 s i m i l a n            i s i l l
# 40               s i m i l a j n          s i m i l l
# 41                     g v i d i              i v i d
# 42                   g v i d a s              v i d e
# 43                   s p e r t o              s e c t
# 44                 s p e r t o n        s e p r e n t
# 45                   s p e r t i            s e r t e
# 46                 s p e r t a s        s p e r t e s
# 47                   p o e n t o            p o n t e
# 48                 p o e n t o n            p o n e t
# 49                       p o m o              p o m e
# 50                     p o m o n              p o m e
# 51                     b l o k o              b o l k
# 52                   b l o k o n              b l o n
# 53                     b l o k i              b l i k
# 54                   b l o k a s            b l o k s
# 55                 b l o k a d o          b l o d e d
# 56               b l o k a d o n          b l o d e d
# 57                       ĵ e t i                e i t
# 58                     ĵ e t a s                e s t
# 59                     ĵ e t i s              b e s t
# 60                 ĵ e t a n t a            t e a n t
# 61               ĵ e t a n t a j          c e t a n t
# 62               ĵ e t a n t a n            c e a n t
# 63             ĵ e t a n t a j n      e c e n t a l y
# 64                       ŝ a t i              a w i t
# 65                     ŝ a t a s                a s t
# 66                       k i e l                i v e
# 67               v e r ŝ a j n e      v e v e r a n y
# 68                       a ŭ d i                a d i
# 69                     a ŭ d a s                a d s
# 70                     a ŭ d i s              a d i s
# 71                 a ŭ d a n t a            a d a n t
# 72               a ŭ d a n t a j  a n d a s t o n d a
# 73               a ŭ d a n t a n      a n d a t a n d
# 74             a ŭ d a n t a j n    a n d a s t a n d
# 75                     t a s k o              t a s e
# 76                   t a s k o n              t a s k
# 77                     t a s k i              t a s i
# 78                   t a s k a s              t a s s
# 79               t a s k a n t a    t a s t e n d a l
# 80             t a s k a n t a j    t a s t a n d i s
# 81             t a s k a n t a n    t a s t a n d a n
# 82           t a s k a n t a j n        t a s t a n d
# 83                       s a ĝ a                s a y
# 84                     s a ĝ a j                s a y
# 85                     s a ĝ a n                s a y
# 86                   s a ĝ a j n                s a y
# 87                       s a ĝ o                s a y
# 88                     s a ĝ o n                s a y
# 89                     i m a g i                i m i
# 90                   i m a g a s              i m a s
# 91                   i m a g i s              i m i s
# 92                     i m a g o                i m e
# 93               i m a g p o v o          m i v a l o
# 94                 i m a g a d o            m i a d e
# 95               k o m p r e n i      r o m e l i n e
# 96             k o m p r e n a s    c o m p e r e n s
# 97             k o m p r e n i s    p o r e m i n s e
# 98           k o m p r e n a d o  h o m p e r e n d a
# 99         k o m p r e n a d o n  p o r m e n d e a n
# 100        k o m p r e n a n t a  p o r e n t a n t e
# 101      k o m p r e n a n t a j    p o r e m a n t e
# 102      k o m p r e n a n t a n  p o r e n a n t e n
# 103    k o m p r e n a n t a j n  p o r e n c a n t e
# 104                  f i k c i o            f i c i n
# 105                f i k c i o n            f i c i n
# 106                  f i k c i a            f i c i n
# 107                f i k c i a j            f i c i n
# 108                f i k c i a n          f i c i n d
# 109              f i k c i a j n      f i c i n a l s
# 110            r e v o l u c i i    r e v i v i l o j
# 111          r e v o l u c i a s      r e v o l i s e
# 112            r e v o l u c i o    r e v o v i l o j
# 113          r e v o l u c i o n      r e v e l i o n
# 114            r e v o l u c i a    r e v o l i v a j
# 115          r e v o l u c i a j  r e v i l o s u a l
# 116          r e v o l u c i a n  r e v e l i o n a l
# 117        r e v o l u c i a j n    r e v e l i o j n
# 118            m a l r i d e t i  m a l i v e r t i d
# 119          m a l r i d e t a s    m a l r e s t e d
# 120          m a l r i d e t i s  m a l t e v i d e s
# 121      m a l r i d e t a n t a  m a l t e d a n t e
# 122    m a l r i d e t a n t a j  m a l t e d a n t e
# 123    m a l r i d e t a n t a n  m a l e r e n t a d
# 124  m a l r i d e t a n t a j n  m a l t e r d a n t
# 125                  g e n e r i            g e r e n
# 126                g e n e r a s          g e n e r s
# 127                g e n e r i s          g e r e n s
# 128              g e n e r a d o  r e n e v e r d a n
# 129            g e n e r a d o n  g e n e r e d a n d
# 130            g e n e r a c i o  r e v e n t o v a r
# 131          g e n e r a c i o n  r e v e n t a r o n
# 132            g e n e r a n t a      g e n t e r a n
# 133          g e n e r a n t a j    g e n t e r a n t
# 134          g e n e r a n t a n  g e n e r e n t a l
# 135        g e n e r a n t a j n      g e n t e r a n
# 136                      k r e i                h e r
# 137                    k r e a s              r e e s
# 138                      e l f o                l e f
# 139                    e l f o n                e l f
# 140                    h a l t o              h a l t
# 141                  h a l t o n              h a l t
# 142                    h a l t i              a l i t
# 143                  h a l t a s            h a l t s
# 144                r e d u k t i          r e d i t e
# 145              r e d u k t a s    r e v e s t u n d
# 146                  h o n o r o              h o o n
# 147                h o n o r o n            o r o n d
# 148                  h o n o r i            o r o n d
# 149                h o n o r a s              h o n s
# 150                    f r a t o              f o r t
# 151                  f r a t o n            f r a n t
# 152                n e b u l o j          b e n u l o
# 153              n e b u l o j n      n e b l o u n s
# 154                  k r e s k i            r e s i d
# 155                k r e s k a s            k r e s s
# 156                  i n v o k i            i v o n d
# 157                i n v o k a s            i n v e s
# 158                  m a r k i s            m a r i s
# 159                m a r k i t a          m a r i t e
# 160              m a r k i t a j    m a r i s t a n y
# 161              m a r k i t a n      m a r i n t a d
# 162            m a r k i t a j n    m a r m e n t i s
# 163                    k a n t i                a n t
# 164                  k a n t a s              a n t s
# 165                    ĉ a n t i                a n t
# 166                  ĉ a n t a s            a n ' s t
# 167                  f e l i ĉ o            f i v e l
# 168                f e l i ĉ o n            l i v e n
# 169                  a l t e c o          a l t e c e
# 170                a l t e c o n          l e c t e n
# 171                  b a l e n o          b a l e n e
# 172                b a l e n o n            b a l e n
# 173                        m i a                m i a
# 174                      m i a j              m i a n
# 175                      m i a n                m i n
# 176                    m i a j n              m i n a
# 177                      v e r o                v e r
# 178                    v e r o n                v e r

# %%
# 0 is a target style, so remain only 1.tsf (1 transformed into 0).
for path in OUTPUT_DIR.glob('*.0.tsf'):
    path.unlink()
