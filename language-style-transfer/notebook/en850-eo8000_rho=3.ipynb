# %%
# !nvidia-smi
# Out:
# Mon Jan  2 03:48:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P0    29W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !python -V
# Out:
# Python 3.8.16

# %%
# !python -c "from tensorflow.python.client import device_lib; print(device_lib.list_local_devices())"
# Out:
# 2023-01-02 03:48:19.808127: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17567429217932908854
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14415560704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 14388264551799181284
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/experimentation/language-style-transfer/code
# Out:
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.max_rows', 200)

# %%
DATA_DIR = Path('../../data')
TRAIN_PAIR = 'en850-eo8000'
DEV_PAIR = 'en-eo'

TRAIN_DIR = DATA_DIR / 'train' / TRAIN_PAIR
DEV_DIR = DATA_DIR / 'dev' / DEV_PAIR
TEST_DIR = DATA_DIR / 'test' / DEV_PAIR
OUTPUT_DIR = Path('../../output') / TRAIN_PAIR / 'rho=3'

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python style_transfer.py \
    --train {TRAIN_DIR}/train \
    --dev {DEV_DIR}/dev \
    --output {OUTPUT_DIR}/dev \
    --vocab {DATA_DIR}/vocab \
    --model {OUTPUT_DIR}/model \
    --steps_per_checkpoint 125 \
    --rho 3
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 1,
#     'dev': '../../data/dev/en-eo/dev',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': False,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../../output/en850-eo8000/rho=3/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../../output/en850-eo8000/rho=3/dev',
#     'rho': 3.0,
#     'steps_per_checkpoint': 125,
#     'test': '',
#     'train': '../../data/train/en850-eo8000/train',
#     'vocab': '../../data/vocab'}
# ------------------------------------------------
# #sents of training file 0: 850
# #sents of training file 1: 8000
# vocabulary size: 37
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code/nn.py:9: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.nn.rnn_cell.GRUCell(dim)
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Creating model with fresh parameters.
# --------------------epoch 1--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [02:20<00:00,  7.76it/s]step 125, time 141s, loss 24.69, rec 19.01, adv 1.89, d0 1.39, d1 1.42
# 100% 125/125 [02:20<00:00,  1.13s/it]
# 100% 21/21 [00:01<00:00, 11.67it/s]
# dev loss 22.64, rec 18.40, adv 1.41, d0 1.42, d1 1.42
# saving model...
# --------------------epoch 2--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [01:10<00:05,  2.93s/it]step 250, time 214s, loss 18.75, rec 12.81, adv 1.98, d0 1.33, d1 1.27
# 100% 125/125 [01:10<00:00,  1.78it/s]
# 100% 21/21 [00:00<00:00, 26.61it/s]
# dev loss 19.94, rec 14.11, adv 1.94, d0 1.44, d1 1.37
# saving model...
# --------------------epoch 3--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:10<00:00, 11.87it/s]step 375, time 227s, loss 17.09, rec 10.92, adv 2.06, d0 1.23, d1 1.28
# 100% 125/125 [00:10<00:00, 12.11it/s]
# 100% 21/21 [00:00<00:00, 25.94it/s]
# dev loss 18.72, rec 11.42, adv 2.43, d0 1.32, d1 1.32
# saving model...
# --------------------epoch 4--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:37<00:00, 12.81it/s]step 500, time 266s, loss 15.12, rec 9.02, adv 2.03, d0 1.23, d1 1.24
# 100% 125/125 [00:37<00:00,  3.32it/s]
# 100% 21/21 [00:00<00:00, 26.37it/s]
# dev loss 17.78, rec 10.09, adv 2.56, d0 1.18, d1 1.20
# saving model...
# --------------------epoch 5--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:40<00:00, 12.59it/s]step 625, time 309s, loss 15.95, rec 9.34, adv 2.20, d0 1.26, d1 1.24
# 100% 125/125 [00:40<00:00,  3.06it/s]
# 100% 21/21 [00:00<00:00, 26.18it/s]
# dev loss 17.91, rec 9.90, adv 2.67, d0 1.74, d1 1.10
# --------------------epoch 6--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:10<00:00, 11.55it/s]step 750, time 321s, loss 15.26, rec 8.69, adv 2.19, d0 1.16, d1 1.18
# 100% 125/125 [00:10<00:00, 11.59it/s]
# 100% 21/21 [00:00<00:00, 25.95it/s]
# dev loss 18.20, rec 10.59, adv 2.54, d0 1.16, d1 1.14
# --------------------epoch 7--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:10<00:00, 10.98it/s]step 875, time 332s, loss 15.82, rec 9.06, adv 2.25, d0 1.14, d1 1.17
# 100% 125/125 [00:10<00:00, 11.37it/s]
# 100% 21/21 [00:00<00:00, 23.69it/s]
# dev loss 16.31, rec 9.20, adv 2.37, d0 1.22, d1 1.02
# saving model...
# --------------------epoch 8--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:10<00:00, 11.28it/s]step 1000, time 346s, loss 16.01, rec 9.34, adv 2.23, d0 1.19, d1 1.15
# 100% 125/125 [00:11<00:00, 11.25it/s]
# 100% 21/21 [00:00<00:00, 26.06it/s]
# dev loss 17.78, rec 10.72, adv 2.35, d0 1.25, d1 0.95
# --------------------epoch 9--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:10<00:00, 10.79it/s]step 1125, time 357s, loss 16.16, rec 9.17, adv 2.33, d0 1.12, d1 1.13
# 100% 125/125 [00:10<00:00, 11.37it/s]
# 100% 21/21 [00:00<00:00, 26.22it/s]
# dev loss 20.34, rec 12.22, adv 2.70, d0 1.21, d1 1.00
# --------------------epoch 10--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 11.87it/s]step 1250, time 369s, loss 16.39, rec 9.23, adv 2.39, d0 1.14, d1 1.11
# 100% 125/125 [00:11<00:00, 11.23it/s]
# 100% 21/21 [00:00<00:00, 26.26it/s]
# dev loss 15.97, rec 9.25, adv 2.24, d0 1.17, d1 1.04
# saving model...
# --------------------epoch 11--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.69it/s]step 1375, time 382s, loss 16.05, rec 8.89, adv 2.39, d0 1.10, d1 1.13
# 100% 125/125 [00:11<00:00, 11.03it/s]
# 100% 21/21 [00:00<00:00, 25.90it/s]
# dev loss 15.29, rec 9.74, adv 1.85, d0 1.23, d1 0.91
# saving model...
# --------------------epoch 12--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 10.26it/s]step 1500, time 396s, loss 16.13, rec 8.84, adv 2.43, d0 1.08, d1 1.13
# 100% 125/125 [00:11<00:00, 11.02it/s]
# 100% 21/21 [00:00<00:00, 26.17it/s]
# dev loss 18.36, rec 10.98, adv 2.46, d0 1.25, d1 1.00
# --------------------epoch 13--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.64it/s]step 1625, time 408s, loss 16.48, rec 9.01, adv 2.49, d0 1.09, d1 1.06
# 100% 125/125 [00:11<00:00, 11.03it/s]
# 100% 21/21 [00:00<00:00, 26.15it/s]
# dev loss 17.08, rec 10.98, adv 2.04, d0 1.33, d1 0.97
# --------------------epoch 14--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 11.01it/s]step 1750, time 420s, loss 17.76, rec 9.21, adv 2.85, d0 1.24, d1 1.07
# 100% 125/125 [00:11<00:00, 10.95it/s]
# 100% 21/21 [00:00<00:00, 25.53it/s]
# dev loss 18.00, rec 10.60, adv 2.47, d0 1.30, d1 0.91
# --------------------epoch 15--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.42it/s]step 1875, time 433s, loss 16.20, rec 8.78, adv 2.47, d0 1.14, d1 1.09
# 100% 125/125 [00:11<00:00, 10.79it/s]
# 100% 21/21 [00:00<00:00, 26.60it/s]
# dev loss 16.10, rec 10.31, adv 1.93, d0 1.36, d1 0.94
# --------------------epoch 16--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 11.07it/s]step 2000, time 445s, loss 16.95, rec 9.01, adv 2.65, d0 1.04, d1 1.13
# 100% 125/125 [00:11<00:00, 10.46it/s]
# 100% 21/21 [00:00<00:00, 26.45it/s]
# dev loss 17.09, rec 10.12, adv 2.32, d0 1.23, d1 0.94
# --------------------epoch 17--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 10.71it/s]step 2125, time 458s, loss 16.68, rec 8.93, adv 2.58, d0 1.01, d1 1.10
# 100% 125/125 [00:11<00:00, 10.82it/s]
# 100% 21/21 [00:00<00:00, 26.16it/s]
# dev loss 19.40, rec 11.96, adv 2.48, d0 1.19, d1 0.92
# --------------------epoch 18--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.51it/s]step 2250, time 470s, loss 17.12, rec 9.26, adv 2.62, d0 0.99, d1 1.04
# 100% 125/125 [00:11<00:00, 10.66it/s]
# 100% 21/21 [00:00<00:00, 26.44it/s]
# dev loss 19.16, rec 11.21, adv 2.65, d0 1.21, d1 0.88
# --------------------epoch 19--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [01:00<00:00, 10.81it/s]step 2375, time 532s, loss 17.72, rec 9.38, adv 2.78, d0 0.99, d1 1.03
# 100% 125/125 [01:00<00:00,  2.06it/s]
# 100% 21/21 [00:00<00:00, 26.67it/s]
# dev loss 18.61, rec 12.16, adv 2.15, d0 1.16, d1 0.90
# --------------------epoch 20--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 11.08it/s]step 2500, time 544s, loss 17.54, rec 9.31, adv 2.74, d0 1.01, d1 1.05
# 100% 125/125 [00:11<00:00, 10.83it/s]
# 100% 21/21 [00:00<00:00, 27.28it/s]
# dev loss 16.32, rec 10.27, adv 2.02, d0 1.23, d1 0.91

# %%
df_train = pd.read_csv(OUTPUT_DIR / 'dev.train_loss.tsv', sep='\t', header=0)
df_dev = pd.read_csv(OUTPUT_DIR / 'dev.dev_loss.tsv', sep='\t', header=0)

best_epoch = df_dev['loss'].argmin()
for path in OUTPUT_DIR.glob('*epoch*.tsf'):
    if f'epoch{best_epoch + 1}' not in str(path):
        path.unlink()

plt.figure(figsize=(15, 4))
for i, name in enumerate(df_train.columns, 1):
    plt.subplot(1, len(df_train.columns), i)
    plt.plot(df_train[name], color='blue', label='train')
    plt.plot(df_dev[name], color='red', label='dev')
    plt.axvline(best_epoch, color='green')
    plt.title(name)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python style_transfer.py \
    --test {TEST_DIR}/test \
    --output {OUTPUT_DIR}/test \
    --vocab {DATA_DIR}/vocab \
    --model {OUTPUT_DIR}/model \
    --load_model true \
    --beam 8
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 8,
#     'dev': '',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': True,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../../output/en850-eo8000/rho=3/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../../output/en850-eo8000/rho=3/test',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '../../data/test/en-eo/test',
#     'train': '',
#     'vocab': '../../data/vocab'}
# ------------------------------------------------
# vocabulary size: 37
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code/nn.py:9: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.nn.rnn_cell.GRUCell(dim)
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading model from ../../output/en850-eo8000/rho=3/model
# 100% 21/21 [00:50<00:00,  2.39s/it]
# test loss 11.78, rec 9.93, adv 1.85, d0 1.24, d1 0.91

# %%
preexisting_words = set(
    line.split('\t')[0]
    for line
    in DATA_DIR.joinpath(f'{DEV_PAIR.split("-")[0]}_word2freq.tsv').read_text(encoding='utf-8').splitlines())

train_words = set(
    ''.join(word.split(' '))
    for word
    in TRAIN_DIR.joinpath('train.0').read_text(encoding='utf-8').splitlines())

tsf_words = [
    ''.join(word.split(' '))
    for word
    in OUTPUT_DIR.joinpath('test.1.tsf').read_text(encoding='utf-8').splitlines()]

print(f'transformed words: {len(tsf_words):,} (unique: {len(set(tsf_words)):,})')
ws = [w for w in tsf_words if w in train_words]
print(f'  preexisting English words seen during training: {len(ws):,} (unique: {len(set(ws)):,})')
ws = [w for w in tsf_words if w not in train_words and w in preexisting_words]
print(f'  preexisting English words not seen during training: {len(ws):,} (unique: {len(set(ws)):,})')
ws = [w for w in tsf_words if w not in preexisting_words]
print(f'  currently not in the English vocabulary: {len(ws):,} (unique: {len(set(ws)):,})')
# Out:
# transformed words: 1,300 (unique: 1,198)
#   preexisting English words seen during training: 52 (unique: 33)
#   preexisting English words not seen during training: 558 (unique: 493)
#   currently not in the English vocabulary: 690 (unique: 672)

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python style_transfer.py \
    --test {TEST_DIR}/paper \
    --output {OUTPUT_DIR}/paper \
    --vocab {DATA_DIR}/vocab \
    --model {OUTPUT_DIR}/model \
    --load_model true \
    --beam 8
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 8,
#     'dev': '',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': True,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../../output/en850-eo8000/rho=3/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../../output/en850-eo8000/rho=3/paper',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '../../data/test/en-eo/paper',
#     'train': '',
#     'vocab': '../../data/vocab'}
# ------------------------------------------------
# vocabulary size: 37
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code/nn.py:9: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.nn.rnn_cell.GRUCell(dim)
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading model from ../../output/en850-eo8000/rho=3/model
# 100% 3/3 [00:09<00:00,  3.14s/it]
# test loss 10.70, rec 9.01, adv 1.68, d0 1.13, d1 1.19

# %%
df_paper = pd.read_csv(TEST_DIR / 'paper.1', header=None)
df_paper.columns = ['original']
df_paper_tsf = pd.read_csv(OUTPUT_DIR / 'paper.1.tsf', header=None)
df_paper_tsf.columns = ['transformed']

df_paper.join(df_paper_tsf)
# Out:
#                         original          transformed
# 0                  a r ĝ e n t o            a r e n t
# 1                a r ĝ e n t o n            a r e n t
# 2                      d a n k i                d a n
# 3                    d a n k a s                a n d
# 4                    b r a n ĉ o              b r a n
# 5                  b r a n ĉ o n            b r a n e
# 6                        m a ĉ o                  m a
# 7                      m a ĉ o n                m a n
# 8                      m a t ĉ o                m a t
# 9                    m a t ĉ o n                m a t
# 10                 s u f i k s o            s u i c e
# 11               s u f i k s o n            s u r i n
# 12                 p r e c i p e            p r e c e
# 13                       f i g o                f i g
# 14                     f i g o n              f i n g
# 15                   t i m e m a              t i m e
# 16                 t i m e m a j              t i m e
# 17                 t i m e m a n              t i m e
# 18               t i m e m a j n          t i m e m a
# 19               g r a n d e g a            g a r e d
# 20             g r a n d e g a j    g r a g i a n d e
# 21             g r a n d e g a n      g r a g a n d e
# 22           g r a n d e g a j n    g a r i g a n d e
# 23                 f r a t i n o            f r a n t
# 24               f r a t i n o n          f a r i n t
# 25                     ŝ t a l o                t a l
# 26                   ŝ t a l o n                t a l
# 27                 d i s k u t i          d u d i s t
# 28               d i s k u t a s          d u d i s t
# 29                   a n t a ŭ a                a n t
# 30                 a n t a ŭ a j            a n t a y
# 31                 a n t a ŭ a n              a n t a
# 32               a n t a ŭ a j n            a n t a y
# 33                   a n t a ŭ e              a n t e
# 34                 a n t a ŭ e n              a n t e
# 35                     s e n d i                s e d
# 36                   s e n d a s              s e n d
# 37                   s i m i l a              s i m l
# 38                 s i m i l a j            s i m l a
# 39                 s i m i l a n            s i m a l
# 40               s i m i l a j n            s i m a l
# 41                     g v i d i                i d e
# 42                   g v i d a s              v i d e
# 43                   s p e r t o              s p e r
# 44                 s p e r t o n            p e r t e
# 45                   s p e r t i              p e r t
# 46                 s p e r t a s          p e r s t a
# 47                   p o e n t o              p e o n
# 48                 p o e n t o n            p e o n t
# 49                       p o m o                  p o
# 50                     p o m o n                  p o
# 51                     b l o k o                b o l
# 52                   b l o k o n              b l o n
# 53                     b l o k i                b o l
# 54                   b l o k a s              b o l s
# 55                 b l o k a d o            b o l t e
# 56               b l o k a d o n          b o l i t e
# 57                       ĵ e t i                  t e
# 58                     ĵ e t a s                e a t
# 59                     ĵ e t i s                t e s
# 60                 ĵ e t a n t a            a t e n t
# 61               ĵ e t a n t a j            a t e n t
# 62               ĵ e t a n t a n            a t e n t
# 63             ĵ e t a n t a j n      a r a n t i o n
# 64                       ŝ a t i                b i t
# 65                     ŝ a t a s                a t e
# 66                       k i e l                  i e
# 67               v e r ŝ a j n e    v e r a k o n g e
# 68                       a ŭ d i                a d e
# 69                     a ŭ d a s                a d e
# 70                     a ŭ d i s                a d e
# 71                 a ŭ d a n t a            a d a n d
# 72               a ŭ d a n t a j      a r a d i a n t
# 73               a ŭ d a n t a n    a r a n d i a n t
# 74             a ŭ d a n t a j n      a l a n d i a n
# 75                     t a s k o                t a s
# 76                   t a s k o n                t a s
# 77                     t a s k i                t a s
# 78                   t a s k a s                t a s
# 79               t a s k a n t a    a t a r i n t a l
# 80             t a s k a n t a j  a t a r i o n t a l
# 81             t a s k a n t a n    a t a r i n t a l
# 82           t a s k a n t a j n    a t a r i n t a l
# 83                       s a ĝ a                s a y
# 84                     s a ĝ a j                s a y
# 85                     s a ĝ a n                  a s
# 86                   s a ĝ a j n                s a y
# 87                       s a ĝ o                s e a
# 88                     s a ĝ o n                s a n
# 89                     i m a g i                i m i
# 90                   i m a g a s              i a m e
# 91                   i m a g i s              i a m e
# 92                     i m a g o                i m e
# 93               i m a g p o v o        p a r i o j n
# 94                 i m a g a d o            a m i d e
# 95               k o m p r e n i      p o r o n i t e
# 96             k o m p r e n a s  p o r o n g a s t e
# 97             k o m p r e n i s    p r o o n s i t e
# 98           k o m p r e n a d o    p r o o g e n t a
# 99         k o m p r e n a d o n  p o r o n d a n t e
# 100        k o m p r e n a n t a  p o r o n t a n t e
# 101      k o m p r e n a n t a j  p r o g o n t a m e
# 102      k o m p r e n a n t a n    p r o l o n t a n
# 103    k o m p r e n a n t a j n    p r o l o n t a n
# 104                  f i k c i o              f i c i
# 105                f i k c i o n            f i c i n
# 106                  f i k c i a              f i c i
# 107                f i k c i a j            f i c i a
# 108                f i k c i a n            f i c i n
# 109              f i k c i a j n    f i f i o n c a j
# 110            r e v o l u c i i    r r o c u l i c e
# 111          r e v o l u c i a s    r e r o l u c i s
# 112            r e v o l u c i o    r e r o u c i o l
# 113          r e v o l u c i o n    r o r o u c i o n
# 114            r e v o l u c i a    r r o c u l i c e
# 115          r e v o l u c i a j    r r o u c i l e s
# 116          r e v o l u c i a n      r o r u l i o n
# 117        r e v o l u c i a j n    r e r o u l i o n
# 118            m a l r i d e t i    p r a l i d e n t
# 119          m a l r i d e t a s    p r a l i d e s t
# 120          m a l r i d e t i s    p r a l i s t e d
# 121      m a l r i d e t a n t a    p r a l i d e n t
# 122    m a l r i d e t a n t a j  p r a l i a n t e d
# 123    m a l r i d e t a n t a n    r a l a d i n t e
# 124  m a l r i d e t a n t a j n  p r a l i g a n t e
# 125                  g e n e r i              e n e r
# 126                g e n e r a s              n e r e
# 127                g e n e r i s              n e r e
# 128              g e n e r a d o      g e r o n a d e
# 129            g e n e r a d o n    g e r o n a n t e
# 130            g e n e r a c i o      g e r i o n g e
# 131          g e n e r a c i o n      g e r i o n g e
# 132            g e n e r a n t a      g r e g a n t e
# 133          g e n e r a n t a j      g r e g a n t e
# 134          g e n e r a n t a n    g r e g a n t e n
# 135        g e n e r a n t a j n  g e r a n g a n t e
# 136                      k r e i                  r e
# 137                    k r e a s                t e r
# 138                      e l f o                f e l
# 139                    e l f o n                f e l
# 140                    h a l t o                h a l
# 141                  h a l t o n            a l t e n
# 142                    h a l t i                a l t
# 143                  h a l t a s              l a s t
# 144                r e d u k t i          r e d u d t
# 145              r e d u k t a s    r r e d u d i s t
# 146                  h o n o r o              h o o n
# 147                h o n o r o n              o r o n
# 148                  h o n o r i              o r o n
# 149                h o n o r a s              o r o n
# 150                    f r a t o              f r a t
# 151                  f r a t o n              f a r t
# 152                n e b u l o j            e n u l y
# 153              n e b u l o j n        l o u n g e s
# 154                  k r e s k i              r e k s
# 155                k r e s k a s            r e a s t
# 156                  i n v o k i                i o n
# 157                i n v o k a s              i o n s
# 158                  m a r k i s              m a r s
# 159                m a r k i t a            m a r t i
# 160              m a r k i t a j      p r a c i o n t
# 161              m a r k i t a n      p a r i o n t a
# 162            m a r k i t a j n      p a r i o n t a
# 163                    k a n t i                a n t
# 164                  k a n t a s              a n t e
# 165                    ĉ a n t i                a n t
# 166                  ĉ a n t a s              a n t e
# 167                  f e l i ĉ o              f e l i
# 168                f e l i ĉ o n            f e l i n
# 169                  a l t e c o              a l t e
# 170                a l t e c o n              a l t e
# 171                  b a l e n o              b a l e
# 172                b a l e n o n            b a l e n
# 173                        m i a                m i a
# 174                      m i a j                m i a
# 175                      m i a n                m i n
# 176                    m i a j n                m a n
# 177                      v e r o                v e r
# 178                    v e r o n                v e r

# %%
# 0 is a target style, so remain only 1.tsf (1 transformed into 0).
for path in OUTPUT_DIR.glob('*.0.tsf'):
    path.unlink()
