# %%
# !nvidia-smi
# Out:
# Mon Jan  2 00:34:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0    33W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !python -V
# Out:
# Python 3.8.16

# %%
# !python -c "from tensorflow.python.client import device_lib; print(device_lib.list_local_devices())"
# Out:
# 2023-01-02 00:34:11.864114: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11455984116001926397
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14415560704
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2528797995944656994
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/experimentation/language-style-transfer/code
# Out:
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

pd.set_option('display.max_rows', 200)

# %%
DATA_DIR = Path('../../data')
TRAIN_PAIR = 'en200-eo8000'
DEV_PAIR = 'en-eo'

TRAIN_DIR = DATA_DIR / 'train' / TRAIN_PAIR
DEV_DIR = DATA_DIR / 'dev' / DEV_PAIR
TEST_DIR = DATA_DIR / 'test' / DEV_PAIR
OUTPUT_DIR = Path('../../output') / TRAIN_PAIR / 'default'

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python style_transfer.py \
    --train {TRAIN_DIR}/train \
    --dev {DEV_DIR}/dev \
    --output {OUTPUT_DIR}/dev \
    --vocab {DATA_DIR}/vocab \
    --model {OUTPUT_DIR}/model \
    --steps_per_checkpoint 125
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 1,
#     'dev': '../../data/dev/en-eo/dev',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': False,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../../output/en200-eo8000/default/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../../output/en200-eo8000/default/dev',
#     'rho': 1,
#     'steps_per_checkpoint': 125,
#     'test': '',
#     'train': '../../data/train/en200-eo8000/train',
#     'vocab': '../../data/vocab'}
# ------------------------------------------------
# #sents of training file 0: 200
# #sents of training file 1: 8000
# vocabulary size: 37
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code/nn.py:9: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.nn.rnn_cell.GRUCell(dim)
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Creating model with fresh parameters.
# --------------------epoch 1--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [02:36<00:00, 12.79it/s]step 125, time 156s, loss 19.89, rec 17.97, adv 1.92, d0 1.32, d1 1.37
# 100% 125/125 [02:36<00:00,  1.25s/it]
# 100% 21/21 [00:02<00:00, 10.36it/s]
# dev loss 20.49, rec 19.25, adv 1.24, d0 1.84, d1 1.60
# saving model...
# --------------------epoch 2--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:41<00:00, 11.73it/s]step 250, time 201s, loss 14.33, rec 11.85, adv 2.48, d0 1.33, d1 1.28
# 100% 125/125 [00:41<00:00,  3.04it/s]
# 100% 21/21 [00:00<00:00, 21.52it/s]
# dev loss 16.94, rec 15.38, adv 1.56, d0 1.48, d1 1.37
# saving model...
# --------------------epoch 3--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:42<00:00, 11.50it/s]step 375, time 245s, loss 11.91, rec 9.33, adv 2.58, d0 1.24, d1 1.16
# 100% 125/125 [00:42<00:00,  2.96it/s]
# 100% 21/21 [00:00<00:00, 27.19it/s]
# dev loss 16.48, rec 14.61, adv 1.87, d0 1.67, d1 1.18
# saving model...
# --------------------epoch 4--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:10<00:00, 10.98it/s]step 500, time 258s, loss 10.82, rec 8.01, adv 2.81, d0 1.23, d1 1.18
# 100% 125/125 [00:10<00:00, 11.45it/s]
# 100% 21/21 [00:00<00:00, 26.92it/s]
# dev loss 15.27, rec 13.14, adv 2.12, d0 1.50, d1 1.03
# saving model...
# --------------------epoch 5--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 12.21it/s]step 625, time 271s, loss 10.92, rec 8.04, adv 2.88, d0 1.25, d1 1.03
# 100% 125/125 [00:11<00:00, 11.23it/s]
# 100% 21/21 [00:00<00:00, 26.98it/s]
# dev loss 14.31, rec 11.38, adv 2.93, d0 1.31, d1 0.86
# saving model...
# --------------------epoch 6--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.58it/s]step 750, time 284s, loss 9.94, rec 7.07, adv 2.87, d0 1.13, d1 0.95
# 100% 125/125 [00:11<00:00, 11.12it/s]
# 100% 21/21 [00:00<00:00, 26.66it/s]
# dev loss 19.35, rec 17.58, adv 1.76, d0 1.84, d1 0.95
# --------------------epoch 7--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 11.28it/s]step 875, time 297s, loss 10.18, rec 7.24, adv 2.94, d0 1.06, d1 0.95
# 100% 125/125 [00:11<00:00, 10.74it/s]
# 100% 21/21 [00:00<00:00, 26.86it/s]
# dev loss 15.63, rec 13.58, adv 2.05, d0 1.90, d1 0.86
# --------------------epoch 8--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:43<00:00, 10.97it/s]step 1000, time 341s, loss 9.85, rec 7.07, adv 2.78, d0 1.04, d1 0.97
# 100% 125/125 [00:44<00:00,  2.84it/s]
# 100% 21/21 [00:00<00:00, 26.95it/s]
# dev loss 18.29, rec 16.15, adv 2.15, d0 1.56, d1 0.87
# --------------------epoch 9--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.63it/s]step 1125, time 354s, loss 9.87, rec 6.99, adv 2.88, d0 1.03, d1 0.93
# 100% 125/125 [00:11<00:00, 10.74it/s]
# 100% 21/21 [00:00<00:00, 27.37it/s]
# dev loss 20.23, rec 17.44, adv 2.79, d0 1.83, d1 0.90
# --------------------epoch 10--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:11<00:00, 10.58it/s]step 1250, time 366s, loss 9.88, rec 6.87, adv 3.01, d0 1.05, d1 0.92
# 100% 125/125 [00:11<00:00, 10.67it/s]
# 100% 21/21 [00:00<00:00, 26.80it/s]
# dev loss 17.55, rec 14.41, adv 3.14, d0 1.69, d1 0.77
# --------------------epoch 11--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.37it/s]step 1375, time 379s, loss 9.62, rec 6.58, adv 3.04, d0 1.02, d1 0.89
# 100% 125/125 [00:11<00:00, 10.64it/s]
# 100% 21/21 [00:00<00:00, 27.13it/s]
# dev loss 16.86, rec 14.24, adv 2.62, d0 1.78, d1 0.82
# --------------------epoch 12--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [01:13<00:00,  9.73it/s]step 1500, time 453s, loss 9.63, rec 6.62, adv 3.00, d0 0.96, d1 0.91
# 100% 125/125 [01:13<00:00,  1.69it/s]
# 100% 21/21 [00:00<00:00, 27.23it/s]
# dev loss 18.34, rec 15.92, adv 2.42, d0 1.45, d1 0.78
# --------------------epoch 13--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.14it/s]step 1625, time 466s, loss 9.89, rec 6.79, adv 3.11, d0 0.94, d1 0.88
# 100% 125/125 [00:11<00:00, 10.43it/s]
# 100% 21/21 [00:00<00:00, 27.06it/s]
# dev loss 16.78, rec 14.12, adv 2.66, d0 1.79, d1 0.95
# --------------------epoch 14--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:11<00:00, 10.32it/s]step 1750, time 479s, loss 9.97, rec 6.70, adv 3.27, d0 0.92, d1 0.90
# 100% 125/125 [00:11<00:00, 10.53it/s]
# 100% 21/21 [00:00<00:00, 26.64it/s]
# dev loss 14.69, rec 12.42, adv 2.27, d0 1.62, d1 0.94
# --------------------epoch 15--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:12<00:00, 10.30it/s]step 1875, time 492s, loss 10.02, rec 6.75, adv 3.27, d0 0.90, d1 0.90
# 100% 125/125 [00:12<00:00, 10.25it/s]
# 100% 21/21 [00:00<00:00, 26.84it/s]
# dev loss 14.91, rec 11.95, adv 2.96, d0 1.81, d1 0.84
# --------------------epoch 16--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:12<00:00, 10.25it/s]step 2000, time 505s, loss 9.95, rec 6.57, adv 3.38, d0 0.93, d1 0.82
# 100% 125/125 [00:12<00:00, 10.31it/s]
# 100% 21/21 [00:00<00:00, 27.20it/s]
# dev loss 17.61, rec 15.42, adv 2.20, d0 1.66, d1 0.93
# --------------------epoch 17--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:12<00:00, 10.18it/s]step 2125, time 518s, loss 10.07, rec 6.68, adv 3.38, d0 0.88, d1 0.83
# 100% 125/125 [00:12<00:00, 10.19it/s]
# 100% 21/21 [00:00<00:00, 26.82it/s]
# dev loss 19.77, rec 16.90, adv 2.88, d0 2.20, d1 0.81
# --------------------epoch 18--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:12<00:00, 10.33it/s]step 2250, time 531s, loss 10.32, rec 6.65, adv 3.68, d0 0.82, d1 0.83
# 100% 125/125 [00:12<00:00, 10.28it/s]
# 100% 21/21 [00:00<00:00, 26.28it/s]
# dev loss 17.97, rec 15.00, adv 2.97, d0 2.22, d1 0.84
# --------------------epoch 19--------------------
# learning_rate: 0.0005   gamma: 0.1
#  99% 124/125 [00:12<00:00, 10.07it/s]step 2375, time 544s, loss 10.15, rec 6.49, adv 3.66, d0 0.82, d1 0.82
# 100% 125/125 [00:12<00:00, 10.33it/s]
# 100% 21/21 [00:00<00:00, 26.77it/s]
# dev loss 17.57, rec 13.04, adv 4.53, d0 2.35, d1 0.67
# --------------------epoch 20--------------------
# learning_rate: 0.0005   gamma: 0.1
#  98% 123/125 [00:12<00:00, 10.13it/s]step 2500, time 557s, loss 10.23, rec 6.50, adv 3.72, d0 0.80, d1 0.81
# 100% 125/125 [00:12<00:00, 10.22it/s]
# 100% 21/21 [00:00<00:00, 26.70it/s]
# dev loss 18.70, rec 15.28, adv 3.42, d0 2.66, d1 0.84

# %%
df_train = pd.read_csv(OUTPUT_DIR / 'dev.train_loss.tsv', sep='\t', header=0)
df_dev = pd.read_csv(OUTPUT_DIR / 'dev.dev_loss.tsv', sep='\t', header=0)

best_epoch = df_dev['loss'].argmin()
for path in OUTPUT_DIR.glob('*epoch*.tsf'):
    if f'epoch{best_epoch + 1}' not in str(path):
        path.unlink()

plt.figure(figsize=(15, 4))
for i, name in enumerate(df_train.columns, 1):
    plt.subplot(1, len(df_train.columns), i)
    plt.plot(df_train[name], color='blue', label='train')
    plt.plot(df_dev[name], color='red', label='dev')
    plt.axvline(best_epoch, color='green')
    plt.title(name)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python style_transfer.py \
    --test {TEST_DIR}/test \
    --output {OUTPUT_DIR}/test \
    --vocab {DATA_DIR}/vocab \
    --model {OUTPUT_DIR}/model \
    --load_model true \
    --beam 8
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 8,
#     'dev': '',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': True,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../../output/en200-eo8000/default/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../../output/en200-eo8000/default/test',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '../../data/test/en-eo/test',
#     'train': '',
#     'vocab': '../../data/vocab'}
# ------------------------------------------------
# vocabulary size: 37
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code/nn.py:9: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.nn.rnn_cell.GRUCell(dim)
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading model from ../../output/en200-eo8000/default/model
# 100% 21/21 [00:57<00:00,  2.74s/it]
# test loss 14.48, rec 11.57, adv 2.92, d0 1.29, d1 0.87

# %%
preexisting_words = set(
    line.split('\t')[0]
    for line
    in DATA_DIR.joinpath(f'{DEV_PAIR.split("-")[0]}_word2freq.tsv').read_text(encoding='utf-8').splitlines())

train_words = set(
    ''.join(word.split(' '))
    for word
    in TRAIN_DIR.joinpath('train.0').read_text(encoding='utf-8').splitlines())

tsf_words = [
    ''.join(word.split(' '))
    for word
    in OUTPUT_DIR.joinpath('test.1.tsf').read_text(encoding='utf-8').splitlines()]

print(f'transformed words: {len(tsf_words):,} (unique: {len(set(tsf_words)):,})')
ws = [w for w in tsf_words if w in train_words]
print(f'  preexisting English words seen during training: {len(ws):,} (unique: {len(set(ws)):,})')
ws = [w for w in tsf_words if w not in train_words and w in preexisting_words]
print(f'  preexisting English words not seen during training: {len(ws):,} (unique: {len(set(ws)):,})')
ws = [w for w in tsf_words if w not in preexisting_words]
print(f'  currently not in the English vocabulary: {len(ws):,} (unique: {len(set(ws)):,})')
# Out:
# transformed words: 1,300 (unique: 1,059)
#   preexisting English words seen during training: 96 (unique: 39)
#   preexisting English words not seen during training: 635 (unique: 472)
#   currently not in the English vocabulary: 569 (unique: 548)

# %%
# !TF_CPP_MIN_LOG_LEVEL=2 python style_transfer.py \
    --test {TEST_DIR}/paper \
    --output {OUTPUT_DIR}/paper \
    --vocab {DATA_DIR}/vocab \
    --model {OUTPUT_DIR}/model \
    --load_model true \
    --beam 8
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# ------------------------------------------------
# {   'batch_size': 64,
#     'beam': 8,
#     'dev': '',
#     'dim_emb': 100,
#     'dim_y': 200,
#     'dim_z': 500,
#     'dropout_keep_prob': 0.5,
#     'embedding': '',
#     'filter_sizes': '1,2,3,4,5',
#     'gamma_decay': 1,
#     'gamma_init': 0.1,
#     'gamma_min': 0.1,
#     'learning_rate': 0.0005,
#     'load_model': True,
#     'max_epochs': 20,
#     'max_seq_length': 20,
#     'max_train_size': -1,
#     'model': '../../output/en200-eo8000/default/model',
#     'n_filters': 128,
#     'n_layers': 1,
#     'online_testing': False,
#     'output': '../../output/en200-eo8000/default/paper',
#     'rho': 1,
#     'steps_per_checkpoint': 1000,
#     'test': '../../data/test/en-eo/paper',
#     'train': '',
#     'vocab': '../../data/vocab'}
# ------------------------------------------------
# vocabulary size: 37
# /content/drive/MyDrive/Colab Notebooks/experimentation/language-style-transfer/code/nn.py:9: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.nn.rnn_cell.GRUCell(dim)
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From style_transfer.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:545: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/keras/layers/rnn/legacy_cells.py:555: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading model from ../../output/en200-eo8000/default/model
# 100% 3/3 [00:10<00:00,  3.56s/it]
# test loss 12.51, rec 9.47, adv 3.04, d0 1.20, d1 0.88

# %%
df_paper = pd.read_csv(TEST_DIR / 'paper.1', header=None)
df_paper.columns = ['original']
df_paper_tsf = pd.read_csv(OUTPUT_DIR / 'paper.1.tsf', header=None)
df_paper_tsf.columns = ['transformed']

df_paper.join(df_paper_tsf)
# Out:
#                         original              transformed
# 0                  a r ĝ e n t o                  w a r e
# 1                a r ĝ e n t o n              a r e a n t
# 2                      d a n k i                    w a n
# 3                    d a n k a s                    w a n
# 4                    b r a n ĉ o                    r a y
# 5                  b r a n ĉ o n                b a r e n
# 6                        m a ĉ o                      m a
# 7                      m a ĉ o n                    m a y
# 8                      m a t ĉ o                    m a t
# 9                    m a t ĉ o n                    m a t
# 10                 s u f i k s o                  s o u m
# 11               s u f i k s o n              s o u m i n
# 12                 p r e c i p e                p h e r e
# 13                       f i g o                    f i f
# 14                     f i g o n                    f i f
# 15                   t i m e m a                  m i m e
# 16                 t i m e m a j                  t m e m
# 17                 t i m e m a n                t h m e m
# 18               t i m e m a j n                t h m e m
# 19               g r a n d e g a              h e r a n d
# 20             g r a n d e g a j          g h a r e n d o
# 21             g r a n d e g a n        g h e r a n d o n
# 22           g r a n d e g a j n        g h a r e n d o n
# 23                 f r a t i n o                f a r i t
# 24               f r a t i n o n              m a r i n t
# 25                     ŝ t a l o                    t h a
# 26                   ŝ t a l o n                    t a l
# 27                 d i s k u t i                u d i s t
# 28               d i s k u t a s                  d u s t
# 29                   a n t a ŭ a                    w a t
# 30                 a n t a ŭ a j                  a t h a
# 31                 a n t a ŭ a n                  w a n t
# 32               a n t a ŭ a j n                    t a y
# 33                   a n t a ŭ e                  w a t e
# 34                 a n t a ŭ e n                  a n t e
# 35                     s e n d i                  s e n d
# 36                   s e n d a s                  s e n d
# 37                   s i m i l a                    h i m
# 38                 s i m i l a j                  s i m l
# 39                 s i m i l a n                  s h i m
# 40               s i m i l a j n                  s h i m
# 41                     g v i d i                    w h i
# 42                   g v i d a s                    h i d
# 43                   s p e r t o                  s e r t
# 44                 s p e r t o n                  s o r e
# 45                   s p e r t i                  s h e r
# 46                 s p e r t a s                  s e r e
# 47                   p o e n t o                    o w e
# 48                 p o e n t o n              p o r e n t
# 49                       p o m o                      o m
# 50                     p o m o n                      o m
# 51                     b l o k o                    b o l
# 52                   b l o k o n                    b o l
# 53                     b l o k i                    b o l
# 54                   b l o k a s                  b o u k
# 55                 b l o k a d o                b o u l d
# 56               b l o k a d o n                m a l d o
# 57                       ĵ e t i                    t h e
# 58                     ĵ e t a s                      t e
# 59                     ĵ e t i s                    t h e
# 60                 ĵ e t a n t a                  t e r e
# 61               ĵ e t a n t a j                  t e a t
# 62               ĵ e t a n t a n                  t e r e
# 63             ĵ e t a n t a j n            t e r a n t y
# 64                       ŝ a t i                    w a t
# 65                     ŝ a t a s                    w a s
# 66                       k i e l                    w h e
# 67               v e r ŝ a j n e          t h e r e a n d
# 68                       a ŭ d i                    w a d
# 69                     a ŭ d a s                      a y
# 70                     a ŭ d i s                    w a s
# 71                 a ŭ d a n t a                  a d a t
# 72               a ŭ d a n t a j            w a n t a r o
# 73               a ŭ d a n t a n        w a n t e r a n d
# 74             a ŭ d a n t a j n        w a n t a r n d o
# 75                     t a s k o                    t a s
# 76                   t a s k o n                  t h a s
# 77                     t a s k i                  t h a s
# 78                   t a s k a s                    t a s
# 79               t a s k a n t a            t h a a s t e
# 80             t a s k a n t a j        t a a s t e r o n
# 81             t a s k a n t a n          t h a s a n t e
# 82           t a s k a n t a j n      t a s a n t e r o n
# 83                       s a ĝ a                    y a s
# 84                     s a ĝ a j                    s a y
# 85                     s a ĝ a n                    s a y
# 86                   s a ĝ a j n                    s a y
# 87                       s a ĝ o                    s a y
# 88                     s a ĝ o n                    s a y
# 89                     i m a g i                    h i m
# 90                   i m a g a s                m a r i s
# 91                   i m a g i s                  m a m i
# 92                     i m a g o                    m a m
# 93               i m a g p o v o        w h o m u l t r o
# 94                 i m a g a d o                m a r i d
# 95               k o m p r e n i      k o m p e r i n t o
# 96             k o m p r e n a s        k o m e r u n a s
# 97             k o m p r e n i s        k o m u r e n i s
# 98           k o m p r e n a d o    k o r m e n d u r o n
# 99         k o m p r e n a d o n        s o r m a n d o n
# 100        k o m p r e n a n t a      s o m e n t r a n t
# 101      k o m p r e n a n t a j    s o m e n t r a n t o
# 102      k o m p r e n a n t a n      k o r m e n t a n t
# 103    k o m p r e n a n t a j n  s o m o n t r e n t a n
# 104                  f i k c i o                  w h i m
# 105                f i k c i o n                  w h i m
# 106                  f i k c i a                  w h i m
# 107                f i k c i a j                  f i m a
# 108                f i k c i a n                  w h i m
# 109              f i k c i a j n        w h i n c a r o n
# 110            r e v o l u c i i    w h e o u l g i g g o
# 111          r e v o l u c i a s      w h o u l e r i d o
# 112            r e v o l u c i o            h e r o u l d
# 113          r e v o l u c i o n          c h e r o u l d
# 114            r e v o l u c i a        w h e r l u l d o
# 115          r e v o l u c i a j        w h e r u l d o j
# 116          r e v o l u c i a n        h h e r u l l d o
# 117        r e v o l u c i a j n        h o r e c u l d o
# 118            m a l r i d e t i      w a m i l t e r i t
# 119          m a l r i d e t a s      m a l d e r i t a s
# 120          m a l r i d e t i s    m a l i d e r t i s t
# 121      m a l r i d e t a n t a      m a l a r t i n t a
# 122    m a l r i d e t a n t a j      m a l a r t i n t o
# 123    m a l r i d e t a n t a n        m a l a r t e n t
# 124  m a l r i d e t a n t a j n      m a l a r t e n t o
# 125                  g e n e r i                  h e r e
# 126                g e n e r a s                  h e r e
# 127                g e n e r i s                h e r e n
# 128              g e n e r a d o            h e r a n d o
# 129            g e n e r a d o n        g h e r e n d o n
# 130            g e n e r a c i o          w h e r e n c o
# 131          g e n e r a c i o n          w h e r e n c o
# 132            g e n e r a n t a          g h e r e n t a
# 133          g e n e r a n t a j        g h e r e n t a j
# 134          g e n e r a n t a n        g h e r e n t a n
# 135        g e n e r a n t a j n        g h e r e n t a n
# 136                      k r e i                    h e r
# 137                    k r e a s                  m a r e
# 138                      e l f o                      h e
# 139                    e l f o n                      h e
# 140                    h a l t o                    w h a
# 141                  h a l t o n                  t h a l
# 142                    h a l t i                  w h i t
# 143                  h a l t a s                  w a t h
# 144                r e d u k t i            w e r u d t o
# 145              r e d u k t a s          w e r u s t u d
# 146                  h o n o r o                  n o r o
# 147                h o n o r o n                h o r o n
# 148                  h o n o r i                o w h o r
# 149                h o n o r a s                  h o r o
# 150                    f r a t o                    f a r
# 151                  f r a t o n                  f r a t
# 152                n e b u l o j                b e u l d
# 153              n e b u l o j n            c e c o u n d
# 154                  k r e s k i                h e r k i
# 155                k r e s k a s                m a r e s
# 156                  i n v o k i                  w i o n
# 157                i n v o k a s                n o m a s
# 158                  m a r k i s                m a r k i
# 159                m a r k i t a                m a r i t
# 160              m a r k i t a j            m a r a s t o
# 161              m a r k i t a n      m a r m a n t i t o
# 162            m a r k i t a j n        m a r m a n t o j
# 163                    k a n t i                    w a t
# 164                  k a n t a s                  w a s t
# 165                    ĉ a n t i                  w h a t
# 166                  ĉ a n t a s                  w a n t
# 167                  f e l i ĉ o                  w h e l
# 168                f e l i ĉ o n                  w h e l
# 169                  a l t e c o                  b a l e
# 170                a l t e c o n                  b a l e
# 171                  b a l e n o                  b e a l
# 172                b a l e n o n                  b a l e
# 173                        m i a                      m a
# 174                      m i a j                      m a
# 175                      m i a n                      m a
# 176                    m i a j n                      m a
# 177                      v e r o                    h e r
# 178                    v e r o n                    h e r

# %%
# 0 is a target style, so remain only 1.tsf (1 transformed into 0).
for path in OUTPUT_DIR.glob('*.0.tsf'):
    path.unlink()
